# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# Define the paths to both train and test datasets
splits = {'train': 'data/train/train.parquet', 'test': 'data/test/test.parquet'}

# Read both datasets
train_df = pd.read_parquet("hf://datasets/raghavdw/cci-dataset-v2/" + splits["train"])
test_df = pd.read_parquet("hf://datasets/raghavdw/cci-dataset-v2/" + splits["test"])

# Combine them into one dataset
combined_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# Now you can work on the combined dataset
print(f"Train shape: {train_df.shape}")
print(f"Test shape: {test_df.shape}")
print(f"Combined shape: {combined_df.shape}")

# You can also reset the index if needed
combined_df = combined_df.reset_index(drop=True)
# Out:
# Train shape: (12478, 12)
# Test shape: (3120, 12)
# Combined shape: (15598, 12)

# %%
combined_df.head()
# Out:
#    Index                                          Utterance Predicted_Intent  \
# 0   2819  Can I get assistance in LHR when I land on my ...     ChangeFlight
# 1   9253  If I book my flight through princess cruise, s...       BookFlight
# 2    220  Okay,arrive in Oslo at 5:00pm and catch Flight...        PetTravel
# 3   7736  I did not see my canceled reservation in my ac...     CancelFlight
# 4     60  I already booked a flight feb. 16th that i wou...       BookFlight
#
#    Intent_Score Sentiment  empathy_score  listening_score  Topic  \
# 0           0.3  POSITIVE              0                0      2
# 1           0.3  POSITIVE              0                0      2
# 2           0.3  POSITIVE              0                0      8
# 3           0.3  NEGATIVE              0                0      2
# 4           0.3  POSITIVE              0                0      2
#
#                         Topic_Name  rsic_score RSICs fallback_type
# 0       Reservations and Ticketing         1.0   Low   no fallback
# 1       Reservations and Ticketing         1.0   Low   no fallback
# 2  Special Services and Assistance         1.0   Low   no fallback
# 3       Reservations and Ticketing         1.0   Low   no fallback
# 4       Reservations and Ticketing         1.0   Low   no fallback

# %%
combined_df["empathy_score"].value_counts()
# Out:
# empathy_score
# 0    15324
# 1      240
# 2       34
# Name: count, dtype: int64

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15598 entries, 0 to 15597
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index             15598 non-null  int64
#  1   Utterance         15598 non-null  object
#  2   Predicted_Intent  15598 non-null  object
#  3   Intent_Score      15598 non-null  float64
#  4   Sentiment         15598 non-null  object
#  5   empathy_score     15598 non-null  int64
#  6   listening_score   15598 non-null  int64
#  7   Topic             15598 non-null  int64
#  8   Topic_Name        15598 non-null  object
#  9   rsic_score        15598 non-null  float64
#  10  RSICs             15598 non-null  object
#  11  fallback_type     15598 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.4+ MB

# %%
combined_df.describe(include="all")
# Out:
#                Index                                          Utterance  \
# count   15598.000000                                              15598
# unique           NaN                                               1752
# top              NaN  How many award miles do I need for a Mileagepl...
# freq             NaN                                                750
# mean     7799.500000                                                NaN
# std      4502.899085                                                NaN
# min         1.000000                                                NaN
# 25%      3900.250000                                                NaN
# 50%      7799.500000                                                NaN
# 75%     11698.750000                                                NaN
# max     15598.000000                                                NaN
#
#        Predicted_Intent  Intent_Score Sentiment  empathy_score  \
# count             15598  15598.000000     15598   15598.000000
# unique               18           NaN         3            NaN
# top               Other           NaN  NEGATIVE            NaN
# freq               5414           NaN      7522            NaN
# mean                NaN      0.301016       NaN       0.019746
# std                 NaN      0.008228       NaN       0.154004
# min                 NaN      0.300000       NaN       0.000000
# 25%                 NaN      0.300000       NaN       0.000000
# 50%                 NaN      0.300000       NaN       0.000000
# 75%                 NaN      0.300000       NaN       0.000000
# max                 NaN      0.375000       NaN       2.000000
#
#         listening_score         Topic                Topic_Name    rsic_score  \
# count      15598.000000  15598.000000                     15598  15598.000000
# unique              NaN           NaN                         9           NaN
# top                 NaN           NaN  General Customer Service           NaN
# freq                NaN           NaN                      6586           NaN
# mean           0.017566      3.550840                       NaN      1.003775
# std            0.131373      2.807851                       NaN      0.082237
# min            0.000000      1.000000                       NaN      1.000000
# 25%            0.000000      1.000000                       NaN      1.000000
# 50%            0.000000      2.000000                       NaN      1.000000
# 75%            0.000000      6.000000                       NaN      1.000000
# max            1.000000     10.000000                       NaN      3.160000
#
#         RSICs fallback_type
# count   15598         15598
# unique      2             1
# top       Low   no fallback
# freq    15582         15598
# mean      NaN           NaN
# std       NaN           NaN
# min       NaN           NaN
# 25%       NaN           NaN
# 50%       NaN           NaN
# 75%       NaN           NaN
# max       NaN           NaN

# %%
combined_df.isna().sum()
# Out:
# Index               0
# Utterance           0
# Predicted_Intent    0
# Intent_Score        0
# Sentiment           0
# empathy_score       0
# listening_score     0
# Topic               0
# Topic_Name          0
# rsic_score          0
# RSICs               0
# fallback_type       0
# dtype: int64

# %%
combined_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
combined_df.columns
# Out:
# Index(['Index', 'Utterance', 'Predicted_Intent', 'Intent_Score', 'Sentiment',
#        'empathy_score', 'listening_score', 'Topic', 'Topic_Name', 'rsic_score',
#        'RSICs', 'fallback_type'],
#       dtype='object')

# %%
combined_df=combined_df.drop(columns=["Index","Predicted_Intent","Intent_Score","rsic_score","RSICs"])

# %%
combined_df.head()
# Out:
#                                            Utterance Sentiment  empathy_score  \
# 0  Can I get assistance in LHR when I land on my ...  POSITIVE              0
# 1  If I book my flight through princess cruise, s...  POSITIVE              0
# 2  Okay,arrive in Oslo at 5:00pm and catch Flight...  POSITIVE              0
# 3  I did not see my canceled reservation in my ac...  NEGATIVE              0
# 4  I already booked a flight feb. 16th that i wou...  POSITIVE              0
#
#    listening_score  Topic                       Topic_Name fallback_type
# 0                0      2       Reservations and Ticketing   no fallback
# 1                0      2       Reservations and Ticketing   no fallback
# 2                0      8  Special Services and Assistance   no fallback
# 3                0      2       Reservations and Ticketing   no fallback
# 4                0      2       Reservations and Ticketing   no fallback

# %%
combined_df['Utterance'] = combined_df['Utterance'].astype(str).str.strip()
combined_df = combined_df[combined_df['Utterance'].str.len() > 3]

combined_df['Sentiment'] = combined_df['Sentiment'].str.lower().str.strip()
combined_df['Topic_Name'] = combined_df['Topic_Name'].astype(str).str.strip()

# %%
combined_df.head()
# Out:
#                                            Utterance Sentiment  empathy_score  \
# 0  Can I get assistance in LHR when I land on my ...  positive              0
# 1  If I book my flight through princess cruise, s...  positive              0
# 2  Okay,arrive in Oslo at 5:00pm and catch Flight...  positive              0
# 3  I did not see my canceled reservation in my ac...  negative              0
# 4  I already booked a flight feb. 16th that i wou...  positive              0
#
#    listening_score  Topic                       Topic_Name fallback_type
# 0                0      2       Reservations and Ticketing   no fallback
# 1                0      2       Reservations and Ticketing   no fallback
# 2                0      8  Special Services and Assistance   no fallback
# 3                0      2       Reservations and Ticketing   no fallback
# 4                0      2       Reservations and Ticketing   no fallback

# %%
combined_df['text_len'] = combined_df['Utterance'].str.len()
combined_df['word_count'] = combined_df['Utterance'].apply(lambda x: len(x.split()))
combined_df['avg_word_len'] = combined_df['text_len'] / combined_df['word_count']

# %%
combined_df['is_negative'] = (combined_df['Sentiment'] == 'negative').astype(int)
combined_df['is_positive'] = (combined_df['Sentiment'] == 'positive').astype(int)
combined_df['is_neutral']  = (combined_df['Sentiment'] == 'neutral').astype(int)

# %%
import re
import string

def clean_text(t):
    t = t.lower()
    t = re.sub(r"http\S+", "", t)
    t = t.translate(str.maketrans("", "", string.punctuation))
    t = re.sub(r'\s+', ' ', t)
    return t.strip()

combined_df['clean_text'] = combined_df['Utterance'].apply(clean_text)

# %%
combined_df = combined_df.dropna(subset=['clean_text', 'Sentiment', 'Topic_Name'])

# %%
combined_df.to_csv("cci_clean_prepared.csv", index=False)
